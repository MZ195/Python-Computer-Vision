# %% [markdown]
# # Detecting faces with HOG

# %%
from PIL import Image
from IPython.display import display
import cv2
import dlib

# %%
image = cv2.imread('../material/Images/people2.jpg')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display(Image.fromarray(image_rgb))
# Out:
# <PIL.Image.Image image mode=RGB size=1023x537 at 0x113FF8E80>

# %%
face_detector_hog = dlib.get_frontal_face_detector()

# %%
detections = face_detector_hog(image_rgb, 1)

# %%
detections, len(detections)
# Out:
# (rectangles[[(429, 38) (465, 74)], [(665, 90) (701, 126)], [(717, 103) (760, 146)], [(909, 70) (952, 113)], [(828, 98) (871, 142)], [(605, 70) (641, 106)], [(777, 62) (813, 98)], [(485, 78) (521, 114)], [(386, 60) (429, 103)], [(170, 41) (213, 84)], [(93, 89) (136, 132)], [(237, 50) (280, 94)], [(323, 50) (367, 94)], [(544, 65) (588, 108)]],
#  14)

# %%
for face in detections:
    l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
    cv2.rectangle(image_rgb, (l, t), (r, b), (0, 255, 255), 2)
display(Image.fromarray(image_rgb))
# Out:
# <PIL.Image.Image image mode=RGB size=1023x537 at 0x1140816A0>
